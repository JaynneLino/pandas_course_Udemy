# %%
import json
import pandas as pd

# %%
df = pd.read_json("dados/receitas.json", encoding= 'utf-8')
df
# Out:
#                                             receitas
# 0  {'titulo': 'Bolo de Chocolate', 'tempo_preparo...
# 1  {'titulo': 'Salada Caesar', 'tempo_preparo': '...
# 2  {'titulo': 'Lasanha de Carne', 'tempo_preparo'...

# %%
df_receitas = pd.json_normalize(
    df['receitas'],
    'ingredientes',
    ['titulo', 'tempo_preparo', 'porcoes']
    )

df_receitas
# Out:
#          ingrediente  quantidade             titulo tempo_preparo porcoes
# 0   Farinha de Trigo   2 xícaras  Bolo de Chocolate    45 minutos       8
# 1             Açúcar    1 xícara  Bolo de Chocolate    45 minutos       8
# 2               Ovos  3 unidades  Bolo de Chocolate    45 minutos       8
# 3              Leite    1 xícara  Bolo de Chocolate    45 minutos       8
# 4           Manteiga  1/2 xícara  Bolo de Chocolate    45 minutos       8
# 5      Alface Romana   1 unidade      Salada Caesar    20 minutos       4
# 6    Frango Grelhado       200 g      Salada Caesar    20 minutos       4
# 7           Croutons    1 xícara      Salada Caesar    20 minutos       4
# 8       Molho Caesar  1/2 xícara      Salada Caesar    20 minutos       4
# 9    Queijo Parmesão  1/4 xícara      Salada Caesar    20 minutos       4
# 10  Massa de Lasanha       500 g   Lasanha de Carne    60 minutos       6
# 11       Carne Moída       400 g   Lasanha de Carne    60 minutos       6
# 12   Molho de Tomate   2 xícaras   Lasanha de Carne    60 minutos       6
# 13  Queijo Mussarela       300 g   Lasanha de Carne    60 minutos       6
# 14          Presunto       200 g   Lasanha de Carne    60 minutos       6
